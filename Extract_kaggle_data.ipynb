# %% [markdown]
# # Extract the Kaggle Data

# %%
# Import all three dependencies
import pandas as pd

# %%
# Create DataFrame
kaggle_metadata = pd.read_csv('movies_metadata.csv', low_memory=False)
ratings = pd.read_csv('ratings.csv')

# %%
# Run head on kaggle_metadata DataFrame
kaggle_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
# Run tail on kaggle_metadata DataFrame
kaggle_metadata.tail()
# Out:
#        adult belongs_to_collection budget  \
# 45461  False                   NaN      0
# 45462  False                   NaN      0
# 45463  False                   NaN      0
# 45464  False                   NaN      0
# 45465  False                   NaN      0
#
#                                                   genres  \
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# ...

# %%
# Run tail on kaggle_metadata DataFrame
kaggle_metadata.sample(5)
# Out:
#        adult belongs_to_collection budget  \
# 22006  False                   NaN      0
# 18805  False                   NaN      0
# 31757  False                   NaN      0
# 42347  False                   NaN      0
# 28480  False                   NaN      0
#
#                                                   genres homepage      id  \
# 22006                [{'id': 99, 'name': 'Documentary'}]      NaN   43208
# 18805                [{'id': 99, 'name': 'Documentary'}]      NaN  251797
# 31757  [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...      NaN   55853
# 42347                     [{'id': 27, 'name': 'Horror'}]      NaN   29896
# 28480  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...      NaN  191726
#
#          imdb_id original_language                        original_title  \
# 22006  tt0420917                en  Snowball Effect: The Story of Clerks
# 18805  tt1543055                en                     Tuntematon emäntä
# ...

# %%
# Run head on ratings DataFrame
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
# Run tail on ratings DataFrame
ratings.tail()
# Out:
#           userId  movieId  rating   timestamp
# 26024284  270896    58559     5.0  1257031564
# 26024285  270896    60069     5.0  1257032032
# 26024286  270896    63082     4.5  1257031764
# 26024287  270896    64957     4.5  1257033990
# 26024288  270896    71878     2.0  1257031858

# %%
# Run sample on ratings DataFrame
ratings.sample(5)
# Out:
#           userId  movieId  rating   timestamp
# 22662240  235443     4643     3.0  1386126662
# 8670784    89397     3415     3.0  1490204296
# 5361970    55295     2826     3.0  1236243648
# 11318812  117436      913     5.0   965296100
# 7752818    79923    66335     3.5  1255362853
